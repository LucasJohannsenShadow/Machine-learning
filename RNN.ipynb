# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
data
# Out:
#           Year     Area  avg_temp   Element_x  Unit_x  yield_amound
# 24        1990    Ghana     26.73  Production  tonnes       5900.00  \
# 25        1990    Ghana     26.73  Production  tonnes       5900.00
# 26        1990    Ghana     26.73  Production  tonnes       5900.00
# 27        1990    Ghana     26.73  Production  tonnes       5900.00
# 28        1990    Ghana     26.73  Production  tonnes       5900.00
# ...        ...      ...       ...         ...     ...           ...
# 15893010  2013  Namibia     20.73  Production  tonnes      60587.49
# 15893011  2013  Namibia     20.73  Production  tonnes      60587.49
# 15893012  2013  Namibia     20.73  Production  tonnes      60587.49
# 15893013  2013  Namibia     20.73  Production  tonnes      60587.49
# 15893014  2013  Namibia     20.73  Production  tonnes      60587.49
#
#                  Element_y                             Item_y
# 24        Agricultural Use                 Pesticides (total)  \
# 25        Agricultural Use                       Insecticides
# 26        Agricultural Use                         Herbicides
# 27        Agricultural Use        Fungicides and Bactericides
# 28        Agricultural Use  Fungicides Ã¢ÂÂ Seed treatments
# ...                    ...                                ...
# 15893010  Agricultural Use                       Insecticides
# 15893011  Agricultural Use                         Herbicides
# 15893012  Agricultural Use        Fungicides and Bactericides
# 15893013  Agricultural Use            Plant Growth Regulators
# 15893014  Agricultural Use                       Rodenticides
#
#           pesticide_amound
# 24                    65.8
# 25                    32.4
# 26                     8.0
# 27                    25.0
# 28                     0.0
# ...                    ...
# 15893010               9.0
# 15893011              17.0
# 15893012              18.0
# 15893013               4.0
# 15893014               8.0
#
# [5936794 rows x 9 columns]

# %%
import pandas as pd
data = pd.read_csv("data/file.csv", encoding='latin-1')
data = data[data["Unit_x"] == "tonnes"]
data = data.drop("Domain", axis= 1)
data = data.drop("Unit_y", axis= 1)
data = data.drop("Item_x", axis=1)
data = data[data("Item_y")== "Pesticides (total)	"]
from sklearn.preprocessing import OneHotEncoder
yield_df_onehot = pd.get_dummies(data, columns=['Area',"Unit_x", "Element_x","Element_y","Item_y"], prefix = ['Area', "Unit_x","Element_x","Element_y" ,"Item_y"])

# %%
model = Sequential()

# Embedding layer
model.add(
    Embedding(input_dim=num_words,
              input_length = training_length,
              output_dim=100,
              weights=[embedding_matrix],
              trainable=False,
              mask_zero=True))

# Masking layer for pre-trained embeddings
model.add(Masking(mask_value=0.0))

# Recurrent layer
model.add(LSTM(64, return_sequences=False, 
               dropout=0.1, recurrent_dropout=0.1))

# Fully connected layer
model.add(Dense(64, activation='relu'))

# Dropout for regularization
model.add(Dropout(0.5))

# Output layer
model.add(Dense(num_words, activation='softmax'))

# Compile the model
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 model = Sequential()
#       3 # Embedding layer
#       4 model.add(
# ----> 5     Embedding(input_dim=num_words,
#       6               input_length = training_length,
#       7               output_dim=100,
#       8               weights=[embedding_matrix],
#       9               trainable=False,
#      10               mask_zero=True))
#      12 # Masking layer for pre-trained embeddings
#      13 model.add(Masking(mask_value=0.0))
#
# NameError: name 'Embedding' is not defined

# %%
model.fit(X_train, y_train, batch_size=32, epochs=10, validation_data=(X_val, y_val))

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# %%
predictions = model.predict(X_new)
